# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
s=pd.Series([1,3,5,np.nan,6,8])

# %%
dates=pd.date_range('20170101',periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2017-01-01', '2017-01-02', '2017-01-03', '2017-01-04',
#                '2017-01-05', '2017-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df=pd.DataFrame(np.random.randn(6,4),index=dates,columns=list('ABCD'))

# %%
df
# Out:
#                    A         B         C         D
# 2017-01-01  0.350745  0.207494  0.662239  0.769864
# 2017-01-02  0.873131  1.383632 -1.272150  0.178533
# 2017-01-03  0.436460 -0.205373  1.231467 -1.923248
# 2017-01-04  0.945366  0.130024 -0.194821  0.228121
# 2017-01-05 -0.754770 -0.844408  1.354590  0.689218
# 2017-01-06  0.800898  1.005895  0.797259 -1.364014

# %%
df.head(1)
# Out:
#                    A         B         C         D
# 2017-01-01  0.350745  0.207494  0.662239  0.769864

# %%
df.tail(2)
# Out:
#                    A         B         C         D
# 2017-01-05 -0.754770 -0.844408  1.354590  0.689218
# 2017-01-06  0.800898  1.005895  0.797259 -1.364014

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.441972  0.279544  0.429764 -0.236921
# std    0.633826  0.809019  0.997371  1.129093
# min   -0.754770 -0.844408 -1.272150 -1.923248
# 25%    0.372173 -0.121524  0.019444 -0.978377
# 50%    0.618679  0.168759  0.729749  0.203327
# 75%    0.855073  0.806295  1.122915  0.573944
# max    0.945366  1.383632  1.354590  0.769864

# %%
df.T
# Out:
#    2017-01-01  2017-01-02  2017-01-03  2017-01-04  2017-01-05  2017-01-06
# A    0.350745    0.873131    0.436460    0.945366   -0.754770    0.800898
# B    0.207494    1.383632   -0.205373    0.130024   -0.844408    1.005895
# C    0.662239   -1.272150    1.231467   -0.194821    1.354590    0.797259
# D    0.769864    0.178533   -1.923248    0.228121    0.689218   -1.364014

# %%
df.sort_index(axis=0,ascending=False)
# Out:
#                    A         B         C         D
# 2017-01-06  0.800898  1.005895  0.797259 -1.364014
# 2017-01-05 -0.754770 -0.844408  1.354590  0.689218
# 2017-01-04  0.945366  0.130024 -0.194821  0.228121
# 2017-01-03  0.436460 -0.205373  1.231467 -1.923248
# 2017-01-02  0.873131  1.383632 -1.272150  0.178533
# 2017-01-01  0.350745  0.207494  0.662239  0.769864

# %%
df[:3]
# Out:
#                    A         B         C         D
# 2017-01-01  0.350745  0.207494  0.662239  0.769864
# 2017-01-02  0.873131  1.383632 -1.272150  0.178533
# 2017-01-03  0.436460 -0.205373  1.231467 -1.923248

# %%
df.loc['2017-01-01']
df.loc[dates[0]]
# Out:
# A    0.350745
# B    0.207494
# C    0.662239
# D    0.769864
# Name: 2017-01-01 00:00:00, dtype: float64

# %%
df.loc[:,'A':'C']
df.loc[:,['A','C']]
# Out:
#                    A         C
# 2017-01-01  0.350745  0.662239
# 2017-01-02  0.873131 -1.272150
# 2017-01-03  0.436460  1.231467
# 2017-01-04  0.945366 -0.194821
# 2017-01-05 -0.754770  1.354590
# 2017-01-06  0.800898  0.797259

# %%
df.iloc[3]
df.iloc[3:5,0:2]
# Out:
#                    A         B
# 2017-01-04  0.945366  0.130024
# 2017-01-05 -0.754770 -0.844408

# %%
df_filter=df[df>0]
df_filter.fillna('zero')
# Out:
#                    A         B         C         D
# 2017-01-01  0.350745  0.207494  0.662239  0.769864
# 2017-01-02  0.873131   1.38363      zero  0.178533
# 2017-01-03   0.43646      zero   1.23147      zero
# 2017-01-04  0.945366  0.130024      zero  0.228121
# 2017-01-05      zero      zero   1.35459  0.689218
# 2017-01-06  0.800898    1.0059  0.797259      zero

# %%
df_copy=df.copy()
df_copy['copy']=['one','two','three',np.nan,np.nan,'six']
df_copy
# Out:
#                    A         B         C         D   copy
# 2017-01-01  0.350745  0.207494  0.662239  0.769864    one
# 2017-01-02  0.873131  1.383632 -1.272150  0.178533    two
# 2017-01-03  0.436460 -0.205373  1.231467 -1.923248  three
# 2017-01-04  0.945366  0.130024 -0.194821  0.228121    NaN
# 2017-01-05 -0.754770 -0.844408  1.354590  0.689218    NaN
# 2017-01-06  0.800898  1.005895  0.797259 -1.364014    six

# %%
df_copy['A+10']=df_copy['A'].apply(lambda x:x+10)
df_copy
# Out:
#                    A         B         C         D   copy       A+10
# 2017-01-01  0.350745  0.207494  0.662239  0.769864    one  10.350745
# 2017-01-02  0.873131  1.383632 -1.272150  0.178533    two  10.873131
# 2017-01-03  0.436460 -0.205373  1.231467 -1.923248  three  10.436460
# 2017-01-04  0.945366  0.130024 -0.194821  0.228121    NaN  10.945366
# 2017-01-05 -0.754770 -0.844408  1.354590  0.689218    NaN   9.245230
# 2017-01-06  0.800898  1.005895  0.797259 -1.364014    six  10.800898

# %%
s=pd.Series([1,3,5,np.nan,6,8],index=dates).shift(2)
s
# Out:
# 2017-01-01    NaN
# 2017-01-02    NaN
# 2017-01-03    1.0
# 2017-01-04    3.0
# 2017-01-05    5.0
# 2017-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s,axis=0)
# Out:
#                    A         B         C         D
# 2017-01-01       NaN       NaN       NaN       NaN
# 2017-01-02       NaN       NaN       NaN       NaN
# 2017-01-03 -0.563540 -1.205373  0.231467 -2.923248
# 2017-01-04 -2.054634 -2.869976 -3.194821 -2.771879
# 2017-01-05 -5.754770 -5.844408 -3.645410 -4.310782
# 2017-01-06       NaN       NaN       NaN       NaN

# %%
df.apply(np.cumsum,axis=1)
df.apply(np.cumsum,axis=0)
# Out:
#                    A         B         C         D
# 2017-01-01  0.350745  0.207494  0.662239  0.769864
# 2017-01-02  1.223876  1.591126 -0.609911  0.948397
# 2017-01-03  1.660335  1.385753  0.621556 -0.974851
# 2017-01-04  2.605701  1.515777  0.426736 -0.746730
# 2017-01-05  1.850931  0.671370  1.781326 -0.057512
# 2017-01-06  2.651829  1.677265  2.578585 -1.421526

# %%
df.apply(lambda x: x.max()-x.min())
# Out:
# A    1.700135
# B    2.228040
# C    2.626740
# D    2.693112
# dtype: float64

# %%
df=pd.DataFrame({'A':['one','one','two','three']*3,
                'B':['A','B','C']*4,
                'C':['foo','foo','foo','bar','bar','bar']*2,
                'D':np.random.randn(12),
                'E':np.random.randn(12)})
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -0.896621  0.323386
# 1     one  B  foo -0.017686  1.399214
# 2     two  C  foo  1.480920  0.916338
# 3   three  A  bar  1.547971 -0.320279
# 4     one  B  bar -0.840301  0.674329
# 5     one  C  bar  1.487945 -0.901084
# 6     two  A  foo -0.602814 -0.366754
# 7   three  B  foo  2.019680 -0.090688
# 8     one  C  foo  0.116259 -1.008867
# 9     one  A  bar  1.046854  2.166271
# 10    two  B  bar -0.782530 -0.294333
# 11  three  C  bar  0.518260 -1.247124

# %%
df_val=pd.pivot_table(df,values='D',index=['A','B'],columns=['C'])
df_val
# Out:
# C             bar       foo
# A     B
# one   A  1.046854 -0.896621
#       B -0.840301 -0.017686
#       C  1.487945  0.116259
# three A  1.547971       NaN
#       B       NaN  2.019680
#       C  0.518260       NaN
# two   A       NaN -0.602814
#       B -0.782530       NaN
#       C       NaN  1.480920

# %%
States=['NY','NY','NY','NY','FL','FL','GA','GA','FL','FL']
data=[1.0,2,3,4,5,6,7,8,9,10]
idx=pd.date_range('1/1/2012',periods=10,freq='MS')
df1=pd.DataFrame(data,index=idx,columns=['Revenue'])
df1['State']=States
df1
# Out:
#             Revenue State
# 2012-01-01      1.0    NY
# 2012-02-01      2.0    NY
# 2012-03-01      3.0    NY
# 2012-04-01      4.0    NY
# 2012-05-01      5.0    FL
# 2012-06-01      6.0    FL
# 2012-07-01      7.0    GA
# 2012-08-01      8.0    GA
# 2012-09-01      9.0    FL
# 2012-10-01     10.0    FL

# %%
data2=[10.0,10.0,9,9,8,8,7,7,6,6]
idx2=pd.date_range('1/1/2013',periods=10,freq='MS')
df2=pd.DataFrame(data2,index=idx2,columns=['Revenue'])
df2['State']=States
df2
# Out:
#             Revenue State
# 2013-01-01     10.0    NY
# 2013-02-01     10.0    NY
# 2013-03-01      9.0    NY
# 2013-04-01      9.0    NY
# 2013-05-01      8.0    FL
# 2013-06-01      8.0    FL
# 2013-07-01      7.0    GA
# 2013-08-01      7.0    GA
# 2013-09-01      6.0    FL
# 2013-10-01      6.0    FL

# %%
df=pd.concat([df1,df2])
df
# Out:
#             Revenue State
# 2012-01-01      1.0    NY
# 2012-02-01      2.0    NY
# 2012-03-01      3.0    NY
# 2012-04-01      4.0    NY
# 2012-05-01      5.0    FL
# 2012-06-01      6.0    FL
# 2012-07-01      7.0    GA
# 2012-08-01      8.0    GA
# 2012-09-01      9.0    FL
# 2012-10-01     10.0    FL
# 2013-01-01     10.0    NY
# 2013-02-01     10.0    NY
# 2013-03-01      9.0    NY
# 2013-04-01      9.0    NY
# 2013-05-01      8.0    FL
# 2013-06-01      8.0    FL
# 2013-07-01      7.0    GA
# 2013-08-01      7.0    GA
# 2013-09-01      6.0    FL
# 2013-10-01      6.0    FL

# %%
newdf=df.copy()
newdf['x-Mean']=abs(newdf['Revenue']-newdf['Revenue'].mean())
newdf['1.96*std']=1.96*newdf['Revenue'].std()
newdf['Outlier']=abs(newdf['Revenue']-newdf['Revenue'].mean())>1.96*newdf['Revenue'].std()
newdf
# Out:
#             Revenue State  x-Mean  1.96*std  Outlier
# 2012-01-01      1.0    NY    5.75  5.200273     True
# 2012-02-01      2.0    NY    4.75  5.200273    False
# 2012-03-01      3.0    NY    3.75  5.200273    False
# 2012-04-01      4.0    NY    2.75  5.200273    False
# 2012-05-01      5.0    FL    1.75  5.200273    False
# 2012-06-01      6.0    FL    0.75  5.200273    False
# 2012-07-01      7.0    GA    0.25  5.200273    False
# 2012-08-01      8.0    GA    1.25  5.200273    False
# 2012-09-01      9.0    FL    2.25  5.200273    False
# 2012-10-01     10.0    FL    3.25  5.200273    False
# 2013-01-01     10.0    NY    3.25  5.200273    False
# 2013-02-01     10.0    NY    3.25  5.200273    False
# 2013-03-01      9.0    NY    2.25  5.200273    False
# 2013-04-01      9.0    NY    2.25  5.200273    False
# 2013-05-01      8.0    FL    1.25  5.200273    False
# 2013-06-01      8.0    FL    1.25  5.200273    False
# 2013-07-01      7.0    GA    0.25  5.200273    False
# 2013-08-01      7.0    GA    0.25  5.200273    False
# 2013-09-01      6.0    FL    0.75  5.200273    False
# 2013-10-01      6.0    FL    0.75  5.200273    False

# %%
newdf=df.copy()
State=newdf.groupby('State')
State
for idx,data in State:
    print(idx,data)
# Out:
# FL             Revenue State
# 2012-05-01      5.0    FL
# 2012-06-01      6.0    FL
# 2012-09-01      9.0    FL
# 2012-10-01     10.0    FL
# 2013-05-01      8.0    FL
# 2013-06-01      8.0    FL
# 2013-09-01      6.0    FL
# 2013-10-01      6.0    FL
# GA             Revenue State
# 2012-07-01      7.0    GA
# 2012-08-01      8.0    GA
# 2013-07-01      7.0    GA
# 2013-08-01      7.0    GA
# NY             Revenue State
# 2012-01-01      1.0    NY
# 2012-02-01      2.0    NY
# 2012-03-01      3.0    NY
# 2012-04-01      4.0    NY
# 2013-01-01     10.0    NY
# 2013-02-01     10.0    NY
# 2013-03-01      9.0    NY
# 2013-04-01      9.0    NY

# %%
newdf=df.copy()
StateMonth=newdf.groupby(['State',lambda x:x.month])

newdf['Outlier']=StateMonth.transform(lambda x:abs(x-x.mean())>1.96*x.std())
newdf['x-Mean']=StateMonth.transform(lambda x:abs(x-x.mean()))
newdf['1.96*std']=StateMonth.transform(lambda x:1.96*x.std())
newdf
# Out:
#             Revenue State  Outlier  x-Mean   1.96*std
# 2012-01-01      1.0    NY    False     4.5  12.473364
# 2012-02-01      2.0    NY    False     4.0  11.087434
# 2012-03-01      3.0    NY    False     3.0   8.315576
# 2012-04-01      4.0    NY    False     2.5   6.929646
# 2012-05-01      5.0    FL    False     1.5   4.157788
# 2012-06-01      6.0    FL    False     1.0   2.771859
# 2012-07-01      7.0    GA    False     0.0   0.000000
# 2012-08-01      8.0    GA    False     0.5   1.385929
# 2012-09-01      9.0    FL    False     1.5   4.157788
# 2012-10-01     10.0    FL    False     2.0   5.543717
# 2013-01-01     10.0    NY    False     4.5  12.473364
# 2013-02-01     10.0    NY    False     4.0  11.087434
# 2013-03-01      9.0    NY    False     3.0   8.315576
# 2013-04-01      9.0    NY    False     2.5   6.929646
# 2013-05-01      8.0    FL    False     1.5   4.157788
# 2013-06-01      8.0    FL    False     1.0   2.771859
# 2013-07-01      7.0    GA    False     0.0   0.000000
# 2013-08-01      7.0    GA    False     0.5   1.385929
# 2013-09-01      6.0    FL    False     1.5   4.157788
# 2013-10-01      6.0    FL    False     2.0   5.543717

# %%
newdf=df.copy()
StateMonth=newdf.groupby(['State',lambda x:x.month])
newdf['Outlier']=StateMonth.transform(lambda x: abs(x-x.mean())>1.96*x.std())
newdf['x-Mean']=StateMonth.transform(lambda x:abs(x-x.mean()))
newdf['1.96*std']=StateMonth.transform(lambda x:1.96*x.std())
newdf
# Out:
#             Revenue State  Outlier  x-Mean   1.96*std
# 2012-01-01      1.0    NY    False     4.5  12.473364
# 2012-02-01      2.0    NY    False     4.0  11.087434
# 2012-03-01      3.0    NY    False     3.0   8.315576
# 2012-04-01      4.0    NY    False     2.5   6.929646
# 2012-05-01      5.0    FL    False     1.5   4.157788
# 2012-06-01      6.0    FL    False     1.0   2.771859
# 2012-07-01      7.0    GA    False     0.0   0.000000
# 2012-08-01      8.0    GA    False     0.5   1.385929
# 2012-09-01      9.0    FL    False     1.5   4.157788
# 2012-10-01     10.0    FL    False     2.0   5.543717
# 2013-01-01     10.0    NY    False     4.5  12.473364
# 2013-02-01     10.0    NY    False     4.0  11.087434
# 2013-03-01      9.0    NY    False     3.0   8.315576
# 2013-04-01      9.0    NY    False     2.5   6.929646
# 2013-05-01      8.0    FL    False     1.5   4.157788
# 2013-06-01      8.0    FL    False     1.0   2.771859
# 2013-07-01      7.0    GA    False     0.0   0.000000
# 2013-08-01      7.0    GA    False     0.5   1.385929
# 2013-09-01      6.0    FL    False     1.5   4.157788
# 2013-10-01      6.0    FL    False     2.0   5.543717

# %%
newdf=df.copy()
State=newdf.groupby('State')
def s(group):
    group['x-Mean']=abs(group['Revenue']-group['Revenue'].mean())
    group['1.96*std']=1.96*group['Revenue'].std()
    group['Outlier']=abs(group['Revenue']-group['Revenue'].mean())>1.96*group['Revenue'].std()
    return group
Newdf2=State.apply(s)
Newdf2
# Out:
#             Revenue State  x-Mean  1.96*std  Outlier
# 2012-01-01      1.0    NY    5.00  7.554813    False
# 2012-02-01      2.0    NY    4.00  7.554813    False
# 2012-03-01      3.0    NY    3.00  7.554813    False
# 2012-04-01      4.0    NY    2.00  7.554813    False
# 2012-05-01      5.0    FL    2.25  3.434996    False
# 2012-06-01      6.0    FL    1.25  3.434996    False
# 2012-07-01      7.0    GA    0.25  0.980000    False
# 2012-08-01      8.0    GA    0.75  0.980000    False
# 2012-09-01      9.0    FL    1.75  3.434996    False
# 2012-10-01     10.0    FL    2.75  3.434996    False
# 2013-01-01     10.0    NY    4.00  7.554813    False
# 2013-02-01     10.0    NY    4.00  7.554813    False
# 2013-03-01      9.0    NY    3.00  7.554813    False
# 2013-04-01      9.0    NY    3.00  7.554813    False
# 2013-05-01      8.0    FL    0.75  3.434996    False
# 2013-06-01      8.0    FL    0.75  3.434996    False
# 2013-07-01      7.0    GA    0.25  0.980000    False
# 2013-08-01      7.0    GA    0.25  0.980000    False
# 2013-09-01      6.0    FL    1.25  3.434996    False
# 2013-10-01      6.0    FL    1.25  3.434996    False

# %%
file_name='./analyzed_american.csv'
Newdf2.to_csv(file_name)

# %%
ts=pd.Series(np.random.randn(1000),index=pd.date_range('1/1/2000',periods=1000))
ts
# Out:
# 2000-01-01    1.459104
# 2000-01-02   -0.844589
# 2000-01-03    1.461288
# 2000-01-04   -0.570241
# 2000-01-05    0.831283
# 2000-01-06    0.649651
# 2000-01-07    0.271642
# 2000-01-08   -0.625713
# 2000-01-09   -0.019403
# 2000-01-10   -1.079593
# 2000-01-11    0.454267
# 2000-01-12    2.715207
# 2000-01-13   -0.086213
# 2000-01-14   -1.243855
# 2000-01-15   -0.581500
# 2000-01-16    0.992575
# 2000-01-17   -1.107551
# 2000-01-18   -1.398746
# 2000-01-19   -1.046165
# 2000-01-20   -2.298296
# 2000-01-21   -0.109412
# 2000-01-22    0.631923
# 2000-01-23   -0.952264
# 2000-01-24   -0.212908
# 2000-01-25    1.803815
# 2000-01-26   -1.010305
# 2000-01-27    0.434778
# 2000-01-28    1.657911
# 2000-01-29   -1.510267
# 2000-01-30    1.390987
#                 ...
# 2002-08-28   -1.097346
# 2002-08-29   -2.427908
# 2002-08-30   -0.219931
# 2002-08-31    1.182860
# 2002-09-01   -1.630341
# 2002-09-02    0.284542
# 2002-09-03    0.723441
# 2002-09-04   -1.305821
# 2002-09-05   -1.976409
# 2002-09-06   -0.211161
# 2002-09-07    0.705287
# 2002-09-08    0.517901
# 2002-09-09   -0.681294
# 2002-09-10    2.106204
# 2002-09-11    1.650400
# 2002-09-12   -0.306403
# 2002-09-13   -1.925412
# 2002-09-14    2.917026
# 2002-09-15    0.407648
# 2002-09-16   -0.266343
# 2002-09-17   -1.088999
# 2002-09-18   -0.568403
# 2002-09-19   -0.330430
# 2002-09-20   -0.696868
# 2002-09-21    0.375833
# 2002-09-22    0.202121
# 2002-09-23   -0.089651
# 2002-09-24   -1.140806
# 2002-09-25   -0.145915
# 2002-09-26    0.199474
# Freq: D, Length: 1000, dtype: float64

# %%
# %matplotlib inline

# %%
ts=ts.cumsum()
ts.plot()
ts.hist()
